# %% [markdown]
# <a href="https://colab.research.google.com/github/VU21CSEN0100405/Frotend-web-development/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.core.display import display, HTML

html_code = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Cricket Legends Hub</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            margin: 0;
            padding: 0;
            background-color: #e8f5e9;
            color: #333;
        }
        header {
            background: #2e7d32;
            color: white;
            padding: 20px;
            text-align: center;
        }
        .container {
            width: 80%;
            margin: auto;
            overflow: hidden;
        }
        .player {
            display: flex;
            margin: 20px 0;
            padding: 10px;
            background: white;
            border-radius: 5px;
        }
        .player img {
            width: 100px;
            margin-right: 20px;
        }
        .map {
            width: 100%;
            height: 400px;
            margin: 20px 0;
        }
    </style>
</head>
<body>

<header>
    <h1>Cricket Legends Hub</h1>
    <p>Explore the profiles and achievements of cricket's greatest players!</p>
</header>

<div class="container">
    <section>
        <h2>Featured Players</h2>
        <div class="player">
            <img src="https://example.com/player1.jpg" alt="Player 1">
            <div>
                <h3>Player Name 1</h3>
                <p>Career Statistics: 5000 runs, 200 wickets</p>
                <p>Notable Achievements: World Cup Winner, 3x Player of the Year</p>
            </div>
        </div>
        <div class="player">
            <img src="https://example.com/player2.jpg" alt="Player 2">
            <div>
                <h3>Player Name 2</h3>
                <p>Career Statistics: 6000 runs, 150 wickets</p>
                <p>Notable Achievements: Fastest century in ODIs</p>
            </div>
        </div>
    </section>

    <section>
        <h2>Interactive Map</h2>
        <div id="map" class="map"></div>
    </section>

    <section>
        <h2>Top Matches</h2>
        <p><a href="https://youtube.com/your_video_link">Watch Highlights of Memorable Match</a></p>
    </section>

    <section>
        <h2>Fan Zone</h2>
        <p>Share your favorite player stories!</p>
        <form id="story-form">
            <textarea placeholder="Your story here..." rows="4" cols="50"></textarea><br>
            <button type="submit">Submit</button>
        </form>
    </section>
</div>

<script>
    // Placeholder for map initialization (use Leaflet.js or another library)
    function initMap() {
        // Map logic here
    }

    document.getElementById("story-form").addEventListener("submit", function(event) {
        event.preventDefault();
        alert("Thank you for your story!");
        // Logic to handle the submitted story
    });

    window.onload = initMap;
</script>

</body>
</html>
"""

# Display the HTML code
display(HTML(html_code))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Cricket Legends Hub</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 0;
#             padding: 0;
#             background-color: #e8f5e9;
#             color: #333;
#         }
#         header {
#             background: #2e7d32;
#             color: white;
#             padding: 20px;
#             text-align: center;
#         }
#         .container {
#             width: 80%;
#             margin: auto;
#             overflow: hidden;
#         }
#         .player {
#             display: flex;
#             margin: 20px 0;
#             padding: 10px;
#             background: white;
#             border-radius: 5px;
#         }
#         .player img {
#             width: 100px;
#             margin-right: 20px;
#         }
#         .map {
# ...
