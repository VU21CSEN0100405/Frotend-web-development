# %% [markdown]
# <a href="https://colab.research.google.com/github/VU21CSEN0100405/Frotend-web-development/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.core.display import display, HTML

html_code = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Movie Buff Central</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            background-color: #f4f4f4;
            margin: 0;
            padding: 0;
            color: #333;
        }
        header {
            background: #333;
            color: #fff;
            padding: 10px 0;
            text-align: center;
        }
        .container {
            width: 80%;
            margin: auto;
            overflow: hidden;
        }
        h1 {
            margin: 0;
        }
        .movie-poster {
            display: flex;
            flex-wrap: wrap;
            justify-content: space-around;
            margin: 20px 0;
        }
        .poster {
            width: 200px;
            margin: 10px;
        }
        .character-bio {
            margin: 20px 0;
            padding: 10px;
            background: #fff;
            border-radius: 5px;
        }
        .quote {
            background: #eee;
            padding: 15px;
            margin: 20px 0;
            border-left: 5px solid #333;
        }
        .trivia-quiz {
            margin: 20px 0;
            padding: 10px;
            background: #fff;
            border-radius: 5px;
        }
    </style>
</head>
<body>

<header>
    <h1>Movie Buff Central</h1>
    <p>Your hub for everything about Harry Potter</p>
</header>

<div class="container">
    <section class="movie-poster">
        <div class="poster">
            <img src="https://example.com/harry_potter_poster1.jpg" alt="Harry Potter Poster 1" style="width:100%;">
        </div>
        <div class="poster">
            <img src="https://example.com/harry_potter_poster2.jpg" alt="Harry Potter Poster 2" style="width:100%;">
        </div>
        <!-- Add more posters as needed -->
    </section>

    <section class="character-bio">
        <h2>Character Bios</h2>
        <div>
            <h3>Harry Potter</h3>
            <img src="https://example.com/harry_potter_character.jpg" alt="Harry Potter Image" style="width:100px; float:left; margin-right:10px;">
            <p>Harry Potter is a young wizard who discovers his magical heritage and attends Hogwarts School of Witchcraft and Wizardry.</p>
        </div>
    </section>

    <section class="trailer">
        <h2>Movie Trailers</h2>
        <iframe width="560" height="315" src="https://www.youtube.com/watch?v=VyHV0BRtdxo" title="Harry Potter Trailer" frameborder="0" allowfullscreen></iframe>
    </section>

    <section class="quote">
        <h2>Quote of the Day</h2>
        <p id="quote">"It does not do to dwell on dreams and forget to live."</p>
    </section>

    <section class="trivia-quiz">
        <h2>Trivia Quiz</h2>
        <p>Question: What is the name of Harry Potter's pet owl?</p>
        <button onclick="alert('Correct Answer!')">Hedwig</button>
        <button onclick="alert('Wrong Answer!')">Scabbers</button>
        <button onclick="alert('Wrong Answer!')">Crookshanks</button>
    </section>
</div>

<script>
    const quotes = [
        "It does not do to dwell on dreams and forget to live.",
        "Happiness can be found even in the darkest of times, if one only remembers to turn on the light.",
        "It matters not what someone is born, but what they grow to be."
    ];

    document.getElementById("quote").innerText = quotes[Math.floor(Math.random() * quotes.length)];
</script>

</body>
</html>
"""

# Display the HTML code
display(HTML(html_code))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Movie Buff Central</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             background-color: #f4f4f4;
#             margin: 0;
#             padding: 0;
#             color: #333;
#         }
#         header {
#             background: #333;
#             color: #fff;
#             padding: 10px 0;
#             text-align: center;
#         }
#         .container {
#             width: 80%;
#             margin: auto;
#             overflow: hidden;
#         }
#         h1 {
#             margin: 0;
#         }
#         .movie-poster {
#             display: flex;
#             flex-wrap: wrap;
#             justify-content: space-around;
#             margin: 20px 0;
#         }
#         .poster {
#             width: 200px;
#             margin: 10px;
#         }
# ...
