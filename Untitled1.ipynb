# %% [markdown]
# <a href="https://colab.research.google.com/github/VU21CSEN0100405/Frotend-web-development/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.core.display import display, HTML

html_code = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>My Digital Showcase</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            margin: 0;
            padding: 0;
            background-color: #f4f4f4;
            color: #333;
        }
        header {
            background: #007BFF;
            color: white;
            padding: 20px;
            text-align: center;
        }
        .container {
            width: 80%;
            margin: auto;
            overflow: hidden;
        }
        .section {
            background: white;
            padding: 20px;
            margin: 20px 0;
            border-radius: 5px;
        }
        .skills, .portfolio {
            display: flex;
            flex-wrap: wrap;
            justify-content: space-around;
        }
        .skill, .project {
            width: 45%;
            margin: 10px;
            padding: 10px;
            background: #e8e8e8;
            border-radius: 5px;
        }
    </style>
</head>
<body>

<header>
    <h1>My Digital Showcase</h1>
    <p>Welcome to my portfolio website!</p>
</header>

<div class="container">
    <section class="section">
        <h2>About Me</h2>
        <p>Hi! I'm PRAVEEN, a Frontend Web Developer with a passion for creating interactive web experiences and exploring new technologies. I have a background in Computer Science, with a Bachelor's degree from GITAM University.</p>
    </section>

    <section class="section">
        <h2>Skills</h2>
        <div class="skills">
            <div class="skill">HTML & CSS</div>
            <div class="skill">JavaScript</div>
            <div class="skill">Python</div>
            <div class="skill">Communication</div>
            <div class="skill">Problem-solving</div>
        </div>
    </section>

    <section class="section">
        <h2>Portfolio</h2>
        <div class="portfolio">
            <div class="project">
                <h3>"My Digital Showcase"</h3>
                <p>Create a personal portfolio website that showcases your skills, projects, and experience. This
website will serve as your digital resume, helping you present yourself to potential employers or client.</p>
                <a href="https://github.com/yourusername/project1" target="_blank">GitHub Repository</a>
            </div>
            <div class="Movie Buff Central">
                <h3>Project 2</h3>
                <p>Develop a fan page dedicated to a popular movie or movie franchise (e.g., Harry Potter, Star
Wars, Marvel Cinematic Universe). This page will serve as a hub for fans to learn more about their favorite
movies and characters.</p>
                <a href="https://github.com/yourusername/project2" target="_blank">GitHub Repository</a>
            </div>
        </div>
    </section>

    <section class="section">
        <h2>Contact Me</h2>
        <form id="contact-form">
            <input type="text" placeholder="Praveen" required><br>
            <input type="email" placeholder="pkr490322@gmail.com" required><br>
            <textarea placeholder="Your Message" rows="4" required></textarea><br>
            <button type="submit">Send</button>
        </form>
    </section>

    <section class="section">
        <h2>Blog (Optional)</h2>
        <p>Coming soon! Check back for my thoughts on industry trends and tutorials.</p>
    </section>
</div>

<script>
    document.getElementById("contact-form").addEventListener("submit", function(event) {
        event.preventDefault();
        alert("Thank you for your message!");
        // Logic to handle the form submission
    });
</script>

</body>
</html>
"""

# Display the HTML code
display(HTML(html_code))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>My Digital Showcase</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 0;
#             padding: 0;
#             background-color: #f4f4f4;
#             color: #333;
#         }
#         header {
#             background: #007BFF;
#             color: white;
#             padding: 20px;
#             text-align: center;
#         }
#         .container {
#             width: 80%;
#             margin: auto;
#             overflow: hidden;
#         }
#         .section {
#             background: white;
#             padding: 20px;
#             margin: 20px 0;
#             border-radius: 5px;
#         }
#         .skills, .portfolio {
#             display: flex;
#             flex-wrap: wrap;
#             justify-content: space-around;
#         }
# ...
